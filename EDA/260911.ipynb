# %%
# pip install folium
# pip install matplotlib
# pip install geopandas
# pip install cartopy
# pip install osmnx

# %%
import osmnx as ox
import matplotlib.pyplot as plt

seoul_gu = [
    "강남구, 서울특별시, 대한민국",
    "강동구, 서울특별시, 대한민국",
    "강북구, 서울특별시, 대한민국",
    "강서구, 서울특별시, 대한민국",
    "관악구, 서울특별시, 대한민국",
    "광진구, 서울특별시, 대한민국",
    "구로구, 서울특별시, 대한민국",
    "금천구, 서울특별시, 대한민국",
    "노원구, 서울특별시, 대한민국",
    "도봉구, 서울특별시, 대한민국",
    "동대문구, 서울특별시, 대한민국",
    "동작구, 서울특별시, 대한민국",
    "마포구, 서울특별시, 대한민국",
    "서대문구, 서울특별시, 대한민국",
    "서초구, 서울특별시, 대한민국",
    "성동구, 서울특별시, 대한민국",
    "성북구, 서울특별시, 대한민국",
    "송파구, 서울특별시, 대한민국",
    "양천구, 서울특별시, 대한민국",
    "영등포구, 서울특별시, 대한민국",
    "용산구, 서울특별시, 대한민국",
    "은평구, 서울특별시, 대한민국",
    "종로구, 서울특별시, 대한민국",
    "중구, 서울특별시, 대한민국",
    "중랑구, 서울특별시, 대한민국",
]

gdf = ox.geocode_to_gdf(seoul_gu)

fig, ax = plt.subplots(figsize=(8, 8))

gdf.plot(
    ax=ax,
    facecolor="white",
    edgecolor="black",
    linewidth=0.8
)

ax.axis("off")
plt.show()

# %%
gyeonggi = [
    "수원시, 경기도, 대한민국",
    "성남시, 경기도, 대한민국",
    "의정부시, 경기도, 대한민국",
    "안양시, 경기도, 대한민국",
    "부천시, 경기도, 대한민국",
    "광명시, 경기도, 대한민국",
    "평택시, 경기도, 대한민국",
    "동두천시, 경기도, 대한민국",
    "안산시, 경기도, 대한민국",
    "고양시, 경기도, 대한민국",
    "과천시, 경기도, 대한민국",
    "구리시, 경기도, 대한민국",
    "남양주시, 경기도, 대한민국",
    "오산시, 경기도, 대한민국",
    "시흥시, 경기도, 대한민국",
    "군포시, 경기도, 대한민국",
    "의왕시, 경기도, 대한민국",
    "하남시, 경기도, 대한민국",
    "용인시, 경기도, 대한민국",
    "파주시, 경기도, 대한민국",
    "이천시, 경기도, 대한민국",
    "안성시, 경기도, 대한민국",
    "김포시, 경기도, 대한민국",
    "화성시, 경기도, 대한민국",
    "광주시, 경기도, 대한민국",
    "양주시, 경기도, 대한민국",
    "포천시, 경기도, 대한민국",
    "여주시, 경기도, 대한민국",
    "연천군, 경기도, 대한민국",
    "가평군, 경기도, 대한민국",
    "양평군, 경기도, 대한민국",
]

import osmnx as ox
import matplotlib.pyplot as plt

gdf = ox.geocode_to_gdf(gyeonggi)

fig, ax = plt.subplots(figsize=(10, 12))

gdf.plot(
    ax=ax,
    facecolor="white",
    edgecolor="black",
    linewidth=0.7
)

ax.axis("off")
plt.show()
